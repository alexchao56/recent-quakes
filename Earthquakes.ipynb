# %% [markdown]
# # Choosing the Live Feed

# %% [markdown]
# We first need to choose a relevant feed for study. If we wanted to choose another feed, we could just copy and paste a different URL into the url variable.

# %%
import urllib
import json
import pandas as pd
from pprint import pprint

url = 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_week.geojson'

# %% [markdown]
# We use the code below to look at the structure of the JSON data.

# %%
d = json.loads(urllib.urlopen(url).read())

data = pd.DataFrame(d.items())

data
# Out:
#           0                                                  1
# 0      type                                  FeatureCollection
# 1  features  [{u'geometry': {u'type': u'Point', u'coordinat...
# 2      bbox  [-179.4843, -56.4946, -3.1, 179.0595, 66.7659,...
# 3  metadata  {u'status': 200, u'count': 1109, u'title': u'U...

# %% [markdown]
# We can see that the data is stored in a dictionary.

# %%
data[1][1][0]
# Out:
# {u'geometry': {u'coordinates': [-118.979, 37.4732, 3.9], u'type': u'Point'},
#  u'id': u'nc72091676',
#  u'properties': {u'alert': None,
#   u'cdi': None,
#   u'code': u'72091676',
#   u'detail': u'http://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc72091676.geojson',
#   u'dmin': 0.14373045,
#   u'felt': None,
#   u'gap': 219.6,
#   u'ids': u',nc72091676,',
#   u'mag': 1.5,
#   u'magType': u'Md',
#   u'mmi': None,
#   u'net': u'nc',
#   u'nst': None,
#   u'place': u'19km S of Mammoth Lakes, California',
#   u'rms': 0.02,
#   u'sig': 35,
#   u'sources': u',nc,',
#   u'status': u'AUTOMATIC',
#   u'time': 1382305508200,
#   u'title': u'M 1.5 - 19km S of Mammoth Lakes, California',
#   u'tsunami': None,
#   u'type': u'earthquake',
#   u'types': u',general-link,geoserve,nearby-cities,origin,phase-data,',
#   u'tz': -420,
#   u'updated': 1382305608743,
#   u'url': u'http://earthquake.usgs.gov/earthquakes/eventpage/nc72091676'},
#  u'type': u'Feature'}

# %% [markdown]
# We can thus write code to extract the desired values from the dictionary.

# %%
earthquakes = []

for categories in data[1][1]:
    
    src = categories['properties']['net']
    code = categories['properties']['code']
    time = categories['properties']['time']
    longitude = categories['geometry']['coordinates'][0]
    latitude = categories['geometry']['coordinates'][1]
    magnitude = categories['properties']['mag']
    depth = categories['geometry']['coordinates'][2]
    nst = categories['properties']['nst']
    place = categories['properties']['place']
    earthquake_columns = [src, code, time, longitude, latitude, magnitude, depth, nst, place]
    
    earthquakes.append(earthquake_columns)

#earthquakes

df = pd.DataFrame(np.array(earthquakes),
 columns = ['Src','Code','Time','Latitude','Longitude','Magnitude','Depth','Nst','Place'])
df[0:20]
# Out:
#    Src      Eqid           Time  Latitude Longitude Magnitude  Depth   Nst  \
# 0   ak  10827316  1382303919000 -152.0249    61.746       2.1    100  None
# 1   ci  11381338  1382301360000 -118.4677   35.6697       1.4    9.6    11
# 2   ak  10827299  1382300507000 -151.0288   61.6809       1.8   49.5  None
# 3   ak  10827296  1382300419000 -140.5906   60.0634       2.4    5.1  None
# 4   us  b000khnw  1382298305380   77.4106   35.7836       5.4  75.29  None
# 5   ak  10827287  1382298138000 -149.8679   63.1862         1   85.9  None
# 6   us  b000khnn  1382297405200  144.7346    13.025       4.6  51.68  None
# 7   us  b000khnk  1382297058150  147.7712   -6.3979       4.8  77.82  None
# 8   us  b000khnc  1382294888080  155.0119   -6.4779       5.1  71.57  None
# 9   ak  10827267  1382294672000 -153.0934   59.1745       3.7   36.2  None
# 10  ci  11381330  1382294569600  -116.744   33.6512         1     16    18
# 11  pr  13293004  1382293978400  -66.9568   17.8349       2.6      4    16
# 12  ci  11381322  1382293767000 -115.6707   32.5243       1.5    7.7    13
# 13  ak  10827257  1382293254000 -150.5674   62.7476       1.5    100  None
# 14  pr  13293002  1382291410300  -68.5006   18.0065       3.4     76    13
# 15  hv  60579796  1382290527000 -155.2637   19.4343       2.4    1.6  None
# 16  ci  11381314  1382289471000 -116.3943    33.039       1.1   10.1    21
# 17  ci  11381306  1382289238700   -116.79   33.6833       1.5   18.2    47
# 18  ci  11381298  1382289200100 -115.7353    32.594       1.7    9.2    10
# 19  ci  11381290  1382288909500 -116.7352   33.5808       1.2   13.8    16
#
#                                            Place
# 0                      104km W of Willow, Alaska
# 1         4km SSW of Wofford Heights, California
# 2                       52km W of Willow, Alaska
# 3                     75km NW of Yakutat, Alaska
# 4                      113km NNE of Thang, India
# 5                   51km WSW of Cantwell, Alaska
# 6               27km S of Inarajan Village, Guam
# 7      25km NNW of Finschhafen, Papua New Guinea
# 8          55km WSW of Panguna, Papua New Guinea
# 9                98km SW of Anchor Point, Alaska
# 10     10km S of Idyllwild-Pine Cove, California
# 11              15km SSW of Guanica, Puerto Rico
# 12                   10km SW of Progreso, Mexico
# 13                 52km NNW of Talkeetna, Alaska
# 14  42km SSE of Boca de Yuma, Dominican Republic
# 15                      2km W of Volcano, Hawaii
# 16                19km ESE of Julian, California
# 17     9km SW of Idyllwild-Pine Cove, California
# 18                    14km W of Progreso, Mexico
# 19                   6km WNW of Anza, California

# %% [markdown]
# This should print out the unique places with earthquakes

# %%
set(df.Src)
# Out:
# set([u'pr',
#      u'ci',
#      u'nm',
#      u'nn',
#      u'mb',
#      u'uu',
#      u'ak',
#      u'nc',
#      u'hv',
#      u'us',
#      u'uw',
#      u'se'])

# %% [markdown]
# Let's look at California

# %%
california = df[df.Src=='ci']
california[0:5]
print california.Longitude[0:5]
california.Latitude[0:5]

# %%
from mpl_toolkits.basemap import Basemap

def plot_quakes(quakes):
    m = Basemap(llcrnrlon=-124.960938,llcrnrlat=41.956070,
                urcrnrlon=-114.062500,urcrnrlat=32.236792,
                resolution='l',area_thresh=1000.,projection='merc',
                lat_0=37.147894,lon_0=-119.599609)
    m.drawcoastlines()
    m.drawcountries()
    m.fillcontinents(color='coral',lake_color='blue')
    m.drawmapboundary(fill_color='aqua')
    x, y = m(quakes.Lon, quakes.Lat)
    m.plot(x, y, 'k.')
    return m

plot_quakes(california)
# Out:
# /usr/lib/pymodules/python2.7/mpl_toolkits/__init__.py:2: UserWarning: Module dap was already imported from None, but /usr/lib/python2.7/dist-packages is being added to sys.path
#   __import__('pkg_resources').declare_namespace(__name__)
